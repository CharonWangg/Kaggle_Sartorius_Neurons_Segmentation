# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# !pip install "git+https://github.com/albumentations-team/albumentations.git"

# %%
import sys
sys.path.append("/content/drive/MyDrive/Kaggle/Sartorius")

# %%
import detectron2
from pathlib import Path
import random, cv2, os
import matplotlib.pyplot as plt
import numpy as np
import pycocotools.mask as mask_util
# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor, DefaultTrainer
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.utils.logger import setup_logger
from detectron2.evaluation.evaluator import DatasetEvaluator
from detectron2.engine import BestCheckpointer
from detectron2.checkpoint import DetectionCheckpointer
from albumentations import *
import torch
import os
from detectron2.data import detection_utils
from utils.aug import MyMapper
from detectron2.solver.build import *
from detectron2.data import build_detection_test_loader, build_detection_train_loader
import warnings
warnings.filterwarnings("ignore")

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
class Config:
  pixel_mean = [128,128,128]
  pixel_std = [13.235,13.235,13.235]
  anchor_generators_sizes = [[8], [16], [32], [64],[128]]
  anchor_generators_aspect_ratios = [[0.5, 1.0, 2.0]]

# %%
# Taken from https://www.kaggle.com/theoviel/competition-metric-map-iou
def precision_at(threshold, iou):
    matches = iou > threshold
    true_positives = np.sum(matches, axis=1) == 1  # Correct objects
    false_positives = np.sum(matches, axis=1) == 0  # Extra objects
    false_negatives = np.sum(matches, axis=0) == 0  # Missed objects
    return np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)

def score(pred, targ):
    pred_masks = pred['instances'].pred_masks.cpu().numpy()
    enc_preds = [mask_util.encode(np.asarray(p, order='F')) for p in pred_masks]
    enc_targs = list(map(lambda x:x['segmentation'], targ))
    ious = mask_util.iou(enc_preds, enc_targs, [0]*len(enc_targs))
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, ious)
        p = tp / (tp + fp + fn)
        prec.append(p)
    return np.mean(prec)

class MAPIOUEvaluator(DatasetEvaluator):
    def __init__(self, dataset_name):
        dataset_dicts = DatasetCatalog.get(dataset_name)
        self.annotations_cache = {item['image_id']:item['annotations'] for item in dataset_dicts}
            
    def reset(self):
        self.scores = []

    def process(self, inputs, outputs):
        for inp, out in zip(inputs, outputs):
            if len(out['instances']) == 0:
                self.scores.append(0)    
            else:
                targ = self.annotations_cache[inp['image_id']]
                self.scores.append(score(out, targ))

    def evaluate(self):
        return {"MaP IoU": np.mean(self.scores)}

class Trainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        return MAPIOUEvaluator(dataset_name)

    # @classmethod
    # def build_train_loader(cls, cfg, sampler=None):
    #     return build_detection_train_loader(
    #         cfg, mapper=MyMapper(cfg), sampler=sampler
    #     )

    def build_hooks(self):
      # copy of cfg
      cfg = self.cfg.clone()

      # build the original model hooks
      hooks = super().build_hooks()

      # add the best checkpointer hook
      hooks.insert(-1, BestCheckpointer(cfg.TEST.EVAL_PERIOD, 
                                        DetectionCheckpointer(self.model, cfg.OUTPUT_DIR),
                                        "MaP IoU",
                                        "max",
                                        ))
      return hooks

    @classmethod
    def build_optimizer(cls,cfg,model) -> torch.optim.Optimizer:
      """
      Build an optimizer from config.
      """
      params = get_default_optimizer_params(
          model,
          base_lr=cfg.SOLVER.BASE_LR,
          weight_decay_norm=cfg.SOLVER.WEIGHT_DECAY_NORM,
          bias_lr_factor=cfg.SOLVER.BIAS_LR_FACTOR,
          weight_decay_bias=cfg.SOLVER.WEIGHT_DECAY_BIAS,
      )
      return maybe_add_gradient_clipping(cfg, torch.optim.AdamW)(
          params,
          lr=cfg.SOLVER.BASE_LR,
          #momentum=cfg.SOLVER.MOMENTUM,
          #nesterov=cfg.SOLVER.NESTEROV,
          weight_decay=cfg.SOLVER.WEIGHT_DECAY,
      )

    @classmethod
    def build_lr_scheduler(cls,cfg, optimizer) -> torch.optim.lr_scheduler._LRScheduler:
      """
      Build a LR scheduler from config.
      """
      name = cfg.SOLVER.LR_SCHEDULER_NAME

      if name == "WarmupMultiStepLR":
          steps = [x for x in cfg.SOLVER.STEPS if x <= cfg.SOLVER.MAX_ITER]
          if len(steps) != len(cfg.SOLVER.STEPS):
              logger = logging.getLogger(__name__)
              logger.warning(
                  "SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. "
                  "These values will be ignored."
              )
          sched = MultiStepParamScheduler(
              values=[cfg.SOLVER.GAMMA ** k for k in range(len(steps) + 1)],
              milestones=steps,
              num_updates=cfg.SOLVER.MAX_ITER,
          )
      elif name == "WarmupCosineLR":
          sched = CosineParamScheduler(1, 1/40)
      elif name == "CyclicLR":
          sched = torch.optim.lr_scheduler.CyclicLR(optimizer,
                                                    base_lr=cfg.SOLVER.BASE_LR, max_lr=5*cfg.SOLVER.BASE_LR,
                                                    base_momentum=0.85, max_momentum=0.95)

      else:
          raise ValueError("Unknown LR scheduler: {}".format(name))

      sched = WarmupParamScheduler(
          sched,
          cfg.SOLVER.WARMUP_FACTOR,
          min(cfg.SOLVER.WARMUP_ITERS / cfg.SOLVER.MAX_ITER, 1.0),
          cfg.SOLVER.WARMUP_METHOD,
      )
      return LRMultiplier(optimizer, multiplier=sched, max_iter=cfg.SOLVER.MAX_ITER)

# %%
def run():
  dataDir = "/content/drive/MyDrive/Kaggle/Sartorius/input/sartorius-cell-instance-segmentation"
  DatasetCatalog.clear()
  MetadataCatalog.clear()
  register_coco_instances(f'sartorius_train',{}, '/content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_train_fold{}.json'.format(fold), dataDir)
  register_coco_instances(f'sartorius_val',{},'/content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold{}.json'.format(fold), dataDir)

  cfg = get_cfg()
  cfg.merge_from_file(model_zoo.get_config_file("Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml"))
  cfg.DATASETS.TRAIN = (f"sartorius_train",)
  cfg.DATASETS.TEST = (f"sartorius_val",)
  # cfg.MODEL.PIXEL_MEAN = Config.pixel_mean
  # cfg.MODEL.PIXEL_STD = Config.pixel_std

  cfg.DATALOADER.NUM_WORKERS = 2
  cfg.MODEL.WEIGHTS = "/content/drive/MyDrive/Kaggle/Sartorius/model/pretrained/cascade_v0/model_final.pth"#model_zoo.get_checkpoint_url("Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml")#"/content/drive/MyDrive/Kaggle/Sartorius/model/pretrained/LIVECell_anchor_based_model.pth"
  cfg.SOLVER.IMS_PER_BATCH = 2
  cfg.SOLVER.BASE_LR = 5e-6
  #cfg.SOLVER.LR_SCHEDULER_NAME = "WarmupCosineLR"
  cfg.SOLVER.MAX_ITER = len(DatasetCatalog.get(f"sartorius_train")) // cfg.SOLVER.IMS_PER_BATCH * 20 #尝试20ep 用lr调整
  #cfg.SOLVER.STEPS = (cfg.SOLVER.MAX_ITER//3,cfg.SOLVER.MAX_ITER*2//3)
  cfg.INPUT.MIN_SIZE_TRAIN = (620,660,700,720,760,800)
  cfg.INPUT.MIN_SIZE_TRAIN_SAMPLING = "choice"
  cfg.MODEL.RPN.BATCH_SIZE_PER_IMAGE = 320
  cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3 
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
  #cfg.TEST.EVAL_PERIOD = 
  cfg.TEST.EVAL_PERIOD = len(DatasetCatalog.get(f"sartorius_train")) // cfg.SOLVER.IMS_PER_BATCH  # Once per epoch

  cfg.INPUT.MASK_FORMAT='bitmask'
  cfg.TEST.DETECTIONS_PER_IMAGE = 1000
  #cfg.MODEL.BACKBONE.FREEZE_AT = 2
  cfg.MODEL.RESNETS.DEPTH = 101
  cfg.MODEL.ANCHOR_GENERATOR.ASPECT_RATIOS = Config.anchor_generators_aspect_ratios
  cfg.MODEL.ANCHOR_GENERATOR.SIZES = Config.anchor_generators_sizes
  cfg.MODEL.RESNETS.OUT_FEATURES = ["res2", "res3", "res4", "res5"]
  cfg.MODEL.FPN.IN_FEATURES = ["res2", "res3", "res4", "res5"]
  cfg.MODEL.FPN.NORM = "GN"
  cfg.MODEL.ROI_HEADS.IN_FEATURES = ["p2", "p3", "p4", "p5","p6"]
  cfg.MODEL.RPN.IN_FEATURES = ["p2", "p3", "p4", "p5", "p6"]

  cfg.MODEL.RESNETS.DEFORM_ON_PER_STAGE = [False, True, True, True] # on Res3,Res4,Res5
  cfg.MODEL.RESNETS.DEFORM_MODULATED = True
  cfg.MODEL.RESNETS.DEFORM_NUM_GROUPS = 2
  cfg.MODEL.RESNETS.NORM = "GN"
  cfg.MODEL.ROI_BOX_HEAD.NAME = "FastRCNNConvFCHead"
  cfg.MODEL.ROI_BOX_HEAD.NUM_CONV = 4
  cfg.MODEL.ROI_BOX_HEAD.NUM_FC = 1
  cfg.MODEL.ROI_BOX_HEAD.NORM = "GN"  
  cfg.MODEL.ROI_BOX_HEAD.POOLER_RESOLUTION = 7
  cfg.MODEL.ROI_BOX_HEAD.CLS_AGNOSTIC_BBOX_REG = True  
  cfg.MODEL.ROI_MASK_HEAD.NUM_CONV = 8
  cfg.MODEL.ROI_MASK_HEAD.NORM = "GN"
  cfg.MODEL.ROI_HEADS.IOU_THRESHOLDS = [0.5]
  cfg.MODEL.ROI_BOX_CASCADE_HEAD.IOUS = (0.5, 0.6, 0.7)

  cfg.MODEL.RPN.POST_NMS_TOPK_TRAIN = 3000
  cfg.MODEL.RPN.POST_NMS_TOPK_TEST = 3000
  
    
  # cfg.MODEL.RPN.BBOX_REG_LOSS_TYPE = "ciou"
  # cfg.MODEL.ROI_BOX_HEAD.BBOX_REG_LOSS_TYPE = "ciou"
  # cfg.MODEL.ROI_BOX_HEAD.BBOX_REG_LOSS_WEIGHT = 10.0
  #cfg.SOLVER.AMP.ENABLED = True

  cfg.OUTPUT_DIR = "/content/drive/MyDrive/Kaggle/Sartorius/model/finetuned/cascade_v0/fold_{}#".format(fold)

  os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
  trainer = Trainer(cfg) 
  trainer.resume_or_load(resume=False)
  trainer.train()

# %%
# 2 的理论score最高
for fold in range(2,6):
  run()

#run_all()
# Out:
# [12/12 19:53:54 d2.data.datasets.coco]: Loaded 485 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_train_fold3.json
# [12/12 19:53:55 d2.data.datasets.coco]: Loaded 485 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_train_fold3.json
# [12/12 19:53:57 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(
#       256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_output2): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_lateral3): Conv2d(
#       512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_output3): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_lateral4): Conv2d(
#       1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_output4): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_lateral5): Conv2d(
#       2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (fpn_output5): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#       (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#     )
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): GroupNorm(32, 64, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): DeformBottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(128, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=128, out_channels=128, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#         )
#         (1): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(128, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=128, out_channels=128, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#         )
#         (2): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(128, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=128, out_channels=128, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#         )
#         (3): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(128, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=128, out_channels=128, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): DeformBottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (1): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (2): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (3): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (4): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (5): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (6): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (7): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (8): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (9): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (10): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (11): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (12): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (13): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (14): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (15): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (16): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (17): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (18): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (19): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (20): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (21): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (22): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(256, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=256, out_channels=256, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): DeformBottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 2048, eps=1e-05, affine=True)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(512, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=512, out_channels=512, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 2048, eps=1e-05, affine=True)
#           )
#         )
#         (1): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(512, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=512, out_channels=512, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 2048, eps=1e-05, affine=True)
#           )
#         )
#         (2): DeformBottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv2_offset): Conv2d(512, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): ModulatedDeformConv(
#             in_channels=512, out_channels=512, kernel_size=(3, 3), stride=1, padding=1, dilation=1, groups=1, deformable_groups=2, bias=False
#             (norm): GroupNorm(32, 512, eps=1e-05, affine=True)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): GroupNorm(32, 2048, eps=1e-05, affine=True)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): CascadeROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#         (4): ROIAlign(output_size=(7, 7), spatial_scale=0.015625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): ModuleList(
#       (0): FastRCNNConvFCHead(
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv3): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv4): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#       )
#       (1): FastRCNNConvFCHead(
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv3): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv4): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#       )
#       (2): FastRCNNConvFCHead(
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv3): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (conv4): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activation): ReLU()
#         )
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#       )
#     )
#     (box_predictor): ModuleList(
#       (0): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#       (1): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#       (2): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#         (4): ROIAlign(output_size=(14, 14), spatial_scale=0.015625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn5): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn6): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn7): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (mask_fcn8): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [12/12 19:53:57 d2.data.datasets.coco]: Loaded 485 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_train_fold3.json
# [12/12 19:53:57 d2.data.build]: Removed 0 images with no usable annotations. 485 images left.
# [12/12 19:53:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(620, 660, 700, 720, 760, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [12/12 19:53:57 d2.data.build]: Using training sampler TrainingSampler
# [12/12 19:53:57 d2.data.common]: Serializing 485 elements to byte tensors and concatenating them all ...
# [12/12 19:53:57 d2.data.common]: Serialized dataset takes 6.87 MiB
# SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [12/12 19:53:59 d2.engine.train_loop]: Starting training from iteration 0
# [12/12 19:54:34 d2.utils.events]:  eta: 2:00:11  iter: 19  total_loss: 3.66  loss_cls_stage0: 0.2652  loss_box_reg_stage0: 0.5345  loss_cls_stage1: 0.2682  loss_box_reg_stage1: 0.9402  loss_cls_stage2: 0.2601  loss_box_reg_stage2: 0.8483  loss_mask: 0.3013  loss_rpn_cls: 0.02951  loss_rpn_loc: 0.1199  time: 1.6202  data_time: 0.2980  lr: 9.9905e-08  max_mem: 10832M
# [12/12 19:55:05 d2.utils.events]:  eta: 1:59:52  iter: 39  total_loss: 3.747  loss_cls_stage0: 0.2717  loss_box_reg_stage0: 0.5438  loss_cls_stage1: 0.2795  loss_box_reg_stage1: 0.8946  loss_cls_stage2: 0.2826  loss_box_reg_stage2: 0.8187  loss_mask: 0.2844  loss_rpn_cls: 0.0483  loss_rpn_loc: 0.1338  time: 1.5924  data_time: 0.1201  lr: 1.9981e-07  max_mem: 10832M
# [12/12 19:55:37 d2.utils.events]:  eta: 1:59:22  iter: 59  total_loss: 3.698  loss_cls_stage0: 0.2699  loss_box_reg_stage0: 0.543  loss_cls_stage1: 0.2645  loss_box_reg_stage1: 0.9159  loss_cls_stage2: 0.2715  loss_box_reg_stage2: 0.8974  loss_mask: 0.2997  loss_rpn_cls: 0.04136  loss_rpn_loc: 0.1072  time: 1.5914  data_time: 0.1664  lr: 2.997e-07  max_mem: 10832M
# [12/12 19:56:08 d2.utils.events]:  eta: 1:58:20  iter: 79  total_loss: 3.69  loss_cls_stage0: 0.2595  loss_box_reg_stage0: 0.5626  loss_cls_stage1: 0.2714  loss_box_reg_stage1: 0.9676  loss_cls_stage2: 0.2731  loss_box_reg_stage2: 0.8781  loss_mask: 0.2957  loss_rpn_cls: 0.03371  loss_rpn_loc: 0.1214  time: 1.5792  data_time: 0.1275  lr: 3.9961e-07  max_mem: 11115M
# [12/12 19:56:39 d2.utils.events]:  eta: 1:56:26  iter: 99  total_loss: 3.751  loss_cls_stage0: 0.2849  loss_box_reg_stage0: 0.5426  loss_cls_stage1: 0.2805  loss_box_reg_stage1: 0.9483  loss_cls_stage2: 0.2727  loss_box_reg_stage2: 0.8536  loss_mask: 0.288  loss_rpn_cls: 0.03516  loss_rpn_loc: 0.1085  time: 1.5704  data_time: 0.1275  lr: 4.995e-07  max_mem: 11115M
# [12/12 19:57:09 d2.utils.events]:  eta: 1:55:50  iter: 119  total_loss: 3.609  loss_cls_stage0: 0.2307  loss_box_reg_stage0: 0.5168  loss_cls_stage1: 0.2415  loss_box_reg_stage1: 0.9599  loss_cls_stage2: 0.255  loss_box_reg_stage2: 0.9191  loss_mask: 0.2917  loss_rpn_cls: 0.02659  loss_rpn_loc: 0.0926  time: 1.5598  data_time: 0.0805  lr: 5.9941e-07  max_mem: 11115M
# [12/12 19:57:40 d2.utils.events]:  eta: 1:55:21  iter: 139  total_loss: 3.53  loss_cls_stage0: 0.2478  loss_box_reg_stage0: 0.5314  loss_cls_stage1: 0.2606  loss_box_reg_stage1: 0.9694  loss_cls_stage2: 0.2601  loss_box_reg_stage2: 0.9172  loss_mask: 0.2915  loss_rpn_cls: 0.03322  loss_rpn_loc: 0.1106  time: 1.5587  data_time: 0.1365  lr: 6.993e-07  max_mem: 11115M
# [12/12 19:58:12 d2.utils.events]:  eta: 1:54:40  iter: 159  total_loss: 3.596  loss_cls_stage0: 0.2399  loss_box_reg_stage0: 0.5372  loss_cls_stage1: 0.2499  loss_box_reg_stage1: 0.9454  loss_cls_stage2: 0.2522  loss_box_reg_stage2: 0.8556  loss_mask: 0.3044  loss_rpn_cls: 0.02992  loss_rpn_loc: 0.122  time: 1.5662  data_time: 0.1894  lr: 7.9921e-07  max_mem: 11115M
# [12/12 19:58:44 d2.utils.events]:  eta: 1:54:18  iter: 179  total_loss: 3.665  loss_cls_stage0: 0.2619  loss_box_reg_stage0: 0.5478  loss_cls_stage1: 0.2632  loss_box_reg_stage1: 0.9316  loss_cls_stage2: 0.2765  loss_box_reg_stage2: 0.8749  loss_mask: 0.3038  loss_rpn_cls: 0.03592  loss_rpn_loc: 0.1063  time: 1.5702  data_time: 0.1705  lr: 8.9911e-07  max_mem: 11115M
# [12/12 19:59:13 d2.utils.events]:  eta: 1:53:27  iter: 199  total_loss: 3.383  loss_cls_stage0: 0.2266  loss_box_reg_stage0: 0.5011  loss_cls_stage1: 0.2221  loss_box_reg_stage1: 0.8905  loss_cls_stage2: 0.2384  loss_box_reg_stage2: 0.8628  loss_mask: 0.2825  loss_rpn_cls: 0.02717  loss_rpn_loc: 0.1045  time: 1.5546  data_time: 0.0245  lr: 9.9901e-07  max_mem: 11115M
# [12/12 19:59:43 d2.utils.events]:  eta: 1:53:23  iter: 219  total_loss: 3.592  loss_cls_stage0: 0.2584  loss_box_reg_stage0: 0.5034  loss_cls_stage1: 0.2547  loss_box_reg_stage1: 0.8869  loss_cls_stage2: 0.2658  loss_box_reg_stage2: 0.924  loss_mask: 0.2946  loss_rpn_cls: 0.04118  loss_rpn_loc: 0.12  time: 1.5523  data_time: 0.0840  lr: 1.0989e-06  max_mem: 11115M
# [12/12 20:00:14 d2.utils.events]:  eta: 1:52:49  iter: 239  total_loss: 3.632  loss_cls_stage0: 0.2472  loss_box_reg_stage0: 0.5403  loss_cls_stage1: 0.2595  loss_box_reg_stage1: 0.9561  loss_cls_stage2: 0.2662  loss_box_reg_stage2: 0.9351  loss_mask: 0.2828  loss_rpn_cls: 0.03596  loss_rpn_loc: 0.09764  time: 1.5499  data_time: 0.1146  lr: 1.1988e-06  max_mem: 11115M
# [12/12 20:00:17 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold3.json
# [12/12 20:00:17 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   shsy5y   | 9350         |   astro    | 2342         |    cort    | 2349         |
# |            |              |            |              |            |              |
# |   total    | 14041        |            |              |            |              |
# [12/12 20:00:17 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/12 20:00:17 d2.data.common]: Serializing 121 elements to byte tensors and concatenating them all ...
# [12/12 20:00:17 d2.data.common]: Serialized dataset takes 1.60 MiB
# [12/12 20:00:17 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold3.json
# [12/12 20:00:18 d2.evaluation.evaluator]: Start inference on 121 batches
# [12/12 20:00:23 d2.evaluation.evaluator]: Inference done 11/121. Dataloading: 0.0012 s/iter. Inference: 0.3986 s/iter. Eval: 0.0660 s/iter. Total: 0.4658 s/iter. ETA=0:00:51
# [12/12 20:00:28 d2.evaluation.evaluator]: Inference done 22/121. Dataloading: 0.0015 s/iter. Inference: 0.3975 s/iter. Eval: 0.0605 s/iter. Total: 0.4597 s/iter. ETA=0:00:45
# [12/12 20:00:33 d2.evaluation.evaluator]: Inference done 33/121. Dataloading: 0.0015 s/iter. Inference: 0.3997 s/iter. Eval: 0.0660 s/iter. Total: 0.4674 s/iter. ETA=0:00:41
# [12/12 20:00:39 d2.evaluation.evaluator]: Inference done 44/121. Dataloading: 0.0015 s/iter. Inference: 0.4011 s/iter. Eval: 0.0730 s/iter. Total: 0.4757 s/iter. ETA=0:00:36
# [12/12 20:00:44 d2.evaluation.evaluator]: Inference done 56/121. Dataloading: 0.0015 s/iter. Inference: 0.3996 s/iter. Eval: 0.0683 s/iter. Total: 0.4695 s/iter. ETA=0:00:30
# [12/12 20:00:50 d2.evaluation.evaluator]: Inference done 68/121. Dataloading: 0.0015 s/iter. Inference: 0.3987 s/iter. Eval: 0.0655 s/iter. Total: 0.4659 s/iter. ETA=0:00:24
# [12/12 20:00:55 d2.evaluation.evaluator]: Inference done 80/121. Dataloading: 0.0015 s/iter. Inference: 0.3980 s/iter. Eval: 0.0630 s/iter. Total: 0.4627 s/iter. ETA=0:00:18
# [12/12 20:01:00 d2.evaluation.evaluator]: Inference done 91/121. Dataloading: 0.0015 s/iter. Inference: 0.3980 s/iter. Eval: 0.0624 s/iter. Total: 0.4621 s/iter. ETA=0:00:13
# [12/12 20:01:05 d2.evaluation.evaluator]: Inference done 103/121. Dataloading: 0.0015 s/iter. Inference: 0.3971 s/iter. Eval: 0.0595 s/iter. Total: 0.4583 s/iter. ETA=0:00:08
# [12/12 20:01:10 d2.evaluation.evaluator]: Inference done 115/121. Dataloading: 0.0015 s/iter. Inference: 0.3964 s/iter. Eval: 0.0578 s/iter. Total: 0.4559 s/iter. ETA=0:00:02
# [12/12 20:01:13 d2.evaluation.evaluator]: Total inference time: 0:00:52.929879 (0.456292 s / iter per device, on 1 devices)
# [12/12 20:01:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:45 (0.396407 s / iter per device, on 1 devices)
# [12/12 20:01:13 d2.engine.defaults]: Evaluation results for sartorius_val in csv format:
# [12/12 20:01:13 d2.evaluation.testing]: copypaste: MaP IoU=0.27630180190563086
# [12/12 20:01:14 d2.engine.hooks]: Saved first model at 0.27630 @ 241 steps
# [12/12 20:01:42 d2.utils.events]:  eta: 1:52:19  iter: 259  total_loss: 3.538  loss_cls_stage0: 0.2377  loss_box_reg_stage0: 0.5023  loss_cls_stage1: 0.2309  loss_box_reg_stage1: 0.9233  loss_cls_stage2: 0.2552  loss_box_reg_stage2: 0.8692  loss_mask: 0.2836  loss_rpn_cls: 0.01951  loss_rpn_loc: 0.0798  time: 1.5457  data_time: 0.0583  lr: 1.2987e-06  max_mem: 11115M
# [12/12 20:02:11 d2.utils.events]:  eta: 1:51:40  iter: 279  total_loss: 3.425  loss_cls_stage0: 0.2379  loss_box_reg_stage0: 0.4992  loss_cls_stage1: 0.2454  loss_box_reg_stage1: 0.9105  loss_cls_stage2: 0.2514  loss_box_reg_stage2: 0.891  loss_mask: 0.2796  loss_rpn_cls: 0.03168  loss_rpn_loc: 0.1106  time: 1.5406  data_time: 0.0535  lr: 1.3986e-06  max_mem: 11115M
# [12/12 20:02:41 d2.utils.events]:  eta: 1:51:11  iter: 299  total_loss: 3.672  loss_cls_stage0: 0.2729  loss_box_reg_stage0: 0.541  loss_cls_stage1: 0.2701  loss_box_reg_stage1: 0.9375  loss_cls_stage2: 0.2667  loss_box_reg_stage2: 0.8978  loss_mask: 0.2953  loss_rpn_cls: 0.03664  loss_rpn_loc: 0.1227  time: 1.5366  data_time: 0.0580  lr: 1.4985e-06  max_mem: 11115M
# [12/12 20:03:10 d2.utils.events]:  eta: 1:50:43  iter: 319  total_loss: 3.39  loss_cls_stage0: 0.2568  loss_box_reg_stage0: 0.4873  loss_cls_stage1: 0.2527  loss_box_reg_stage1: 0.8878  loss_cls_stage2: 0.2594  loss_box_reg_stage2: 0.8281  loss_mask: 0.276  loss_rpn_cls: 0.03353  loss_rpn_loc: 0.1164  time: 1.5329  data_time: 0.0588  lr: 1.5984e-06  max_mem: 11115M
# [12/12 20:03:40 d2.utils.events]:  eta: 1:50:12  iter: 339  total_loss: 3.575  loss_cls_stage0: 0.2348  loss_box_reg_stage0: 0.5345  loss_cls_stage1: 0.2501  loss_box_reg_stage1: 0.9102  loss_cls_stage2: 0.2549  loss_box_reg_stage2: 0.909  loss_mask: 0.2902  loss_rpn_cls: 0.02491  loss_rpn_loc: 0.08365  time: 1.5288  data_time: 0.0409  lr: 1.6983e-06  max_mem: 11115M
# [12/12 20:04:12 d2.utils.events]:  eta: 1:49:43  iter: 359  total_loss: 3.385  loss_cls_stage0: 0.2778  loss_box_reg_stage0: 0.5246  loss_cls_stage1: 0.2629  loss_box_reg_stage1: 0.8874  loss_cls_stage2: 0.263  loss_box_reg_stage2: 0.8714  loss_mask: 0.2951  loss_rpn_cls: 0.03232  loss_rpn_loc: 0.1194  time: 1.5335  data_time: 0.1674  lr: 1.7982e-06  max_mem: 11115M
# [12/12 20:04:45 d2.utils.events]:  eta: 1:49:13  iter: 379  total_loss: 3.582  loss_cls_stage0: 0.274  loss_box_reg_stage0: 0.5234  loss_cls_stage1: 0.2752  loss_box_reg_stage1: 0.9341  loss_cls_stage2: 0.2673  loss_box_reg_stage2: 0.9151  loss_mask: 0.297  loss_rpn_cls: 0.02616  loss_rpn_loc: 0.09588  time: 1.5407  data_time: 0.2233  lr: 1.8981e-06  max_mem: 11115M
# [12/12 20:05:18 d2.utils.events]:  eta: 1:48:45  iter: 399  total_loss: 3.668  loss_cls_stage0: 0.2621  loss_box_reg_stage0: 0.539  loss_cls_stage1: 0.2724  loss_box_reg_stage1: 0.9303  loss_cls_stage2: 0.2855  loss_box_reg_stage2: 0.8224  loss_mask: 0.3066  loss_rpn_cls: 0.04054  loss_rpn_loc: 0.1247  time: 1.5462  data_time: 0.1893  lr: 1.998e-06  max_mem: 11115M
# [12/12 20:05:50 d2.utils.events]:  eta: 1:48:24  iter: 419  total_loss: 3.627  loss_cls_stage0: 0.2888  loss_box_reg_stage0: 0.5355  loss_cls_stage1: 0.2902  loss_box_reg_stage1: 0.8871  loss_cls_stage2: 0.2836  loss_box_reg_stage2: 0.8063  loss_mask: 0.2983  loss_rpn_cls: 0.0389  loss_rpn_loc: 0.14  time: 1.5473  data_time: 0.1127  lr: 2.0979e-06  max_mem: 11115M
# [12/12 20:06:21 d2.utils.events]:  eta: 1:47:45  iter: 439  total_loss: 3.346  loss_cls_stage0: 0.1935  loss_box_reg_stage0: 0.4957  loss_cls_stage1: 0.2058  loss_box_reg_stage1: 0.8934  loss_cls_stage2: 0.2308  loss_box_reg_stage2: 0.9442  loss_mask: 0.2962  loss_rpn_cls: 0.01989  loss_rpn_loc: 0.05618  time: 1.5483  data_time: 0.1737  lr: 2.1978e-06  max_mem: 11115M
# [12/12 20:06:52 d2.utils.events]:  eta: 1:47:16  iter: 459  total_loss: 3.587  loss_cls_stage0: 0.2301  loss_box_reg_stage0: 0.5165  loss_cls_stage1: 0.2357  loss_box_reg_stage1: 0.9139  loss_cls_stage2: 0.2488  loss_box_reg_stage2: 0.8713  loss_mask: 0.2977  loss_rpn_cls: 0.03244  loss_rpn_loc: 0.1091  time: 1.5476  data_time: 0.1017  lr: 2.2977e-06  max_mem: 11115M
# [12/12 20:07:20 d2.utils.events]:  eta: 1:46:38  iter: 479  total_loss: 3.478  loss_cls_stage0: 0.208  loss_box_reg_stage0: 0.5448  loss_cls_stage1: 0.2413  loss_box_reg_stage1: 0.8962  loss_cls_stage2: 0.2508  loss_box_reg_stage2: 0.8552  loss_mask: 0.3005  loss_rpn_cls: 0.01802  loss_rpn_loc: 0.06958  time: 1.5417  data_time: 0.0180  lr: 2.3976e-06  max_mem: 11115M
# [12/12 20:07:27 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold3.json
# [12/12 20:07:27 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/12 20:07:27 d2.data.common]: Serializing 121 elements to byte tensors and concatenating them all ...
# [12/12 20:07:27 d2.data.common]: Serialized dataset takes 1.60 MiB
# [12/12 20:07:27 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold3.json
# [12/12 20:07:27 d2.evaluation.evaluator]: Start inference on 121 batches
# [12/12 20:07:32 d2.evaluation.evaluator]: Inference done 11/121. Dataloading: 0.0012 s/iter. Inference: 0.3985 s/iter. Eval: 0.0688 s/iter. Total: 0.4685 s/iter. ETA=0:00:51
# ...
# [12/13 02:48:17 d2.evaluation.evaluator]: Total inference time: 0:00:54.184615 (0.467109 s / iter per device, on 1 devices)
# [12/13 02:48:17 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.399794 s / iter per device, on 1 devices)
# [12/13 02:48:17 d2.engine.defaults]: Evaluation results for sartorius_val in csv format:
# [12/13 02:48:17 d2.evaluation.testing]: copypaste: MaP IoU=0.2728816629597635
# [12/13 02:48:19 d2.engine.hooks]: Saved best model as latest eval score for MaP IoU is 0.27288, better than last best score 0.27131 @ iteration 967.
# [12/13 02:48:25 d2.utils.events]:  eta: 0:11:42  iter: 4359  total_loss: 3.628  loss_cls_stage0: 0.28  loss_box_reg_stage0: 0.5386  loss_cls_stage1: 0.2984  loss_box_reg_stage1: 0.8923  loss_cls_stage2: 0.2941  loss_box_reg_stage2: 0.8548  loss_mask: 0.289  loss_rpn_cls: 0.03767  loss_rpn_loc: 0.1386  time: 1.5320  data_time: 0.2395  lr: 5e-06  max_mem: 11775M
# [12/13 02:48:56 d2.utils.events]:  eta: 0:11:12  iter: 4379  total_loss: 3.372  loss_cls_stage0: 0.2004  loss_box_reg_stage0: 0.49  loss_cls_stage1: 0.2319  loss_box_reg_stage1: 0.8741  loss_cls_stage2: 0.2497  loss_box_reg_stage2: 0.9571  loss_mask: 0.2788  loss_rpn_cls: 0.0256  loss_rpn_loc: 0.0647  time: 1.5320  data_time: 0.1088  lr: 5e-06  max_mem: 11775M
# [12/13 02:49:27 d2.utils.events]:  eta: 0:10:44  iter: 4399  total_loss: 3.588  loss_cls_stage0: 0.2339  loss_box_reg_stage0: 0.5126  loss_cls_stage1: 0.2422  loss_box_reg_stage1: 0.8393  loss_cls_stage2: 0.2559  loss_box_reg_stage2: 0.894  loss_mask: 0.2822  loss_rpn_cls: 0.03599  loss_rpn_loc: 0.1236  time: 1.5321  data_time: 0.1320  lr: 5e-06  max_mem: 11775M
# [12/13 02:49:56 d2.utils.events]:  eta: 0:10:14  iter: 4419  total_loss: 3.309  loss_cls_stage0: 0.2172  loss_box_reg_stage0: 0.4864  loss_cls_stage1: 0.2549  loss_box_reg_stage1: 0.9  loss_cls_stage2: 0.2619  loss_box_reg_stage2: 0.9179  loss_mask: 0.2774  loss_rpn_cls: 0.02397  loss_rpn_loc: 0.07217  time: 1.5318  data_time: 0.0260  lr: 5e-06  max_mem: 11775M
# [12/13 02:50:27 d2.utils.events]:  eta: 0:09:45  iter: 4439  total_loss: 3.419  loss_cls_stage0: 0.1903  loss_box_reg_stage0: 0.4949  loss_cls_stage1: 0.1934  loss_box_reg_stage1: 0.9065  loss_cls_stage2: 0.2417  loss_box_reg_stage2: 0.8426  loss_mask: 0.271  loss_rpn_cls: 0.02872  loss_rpn_loc: 0.04628  time: 1.5319  data_time: 0.1368  lr: 5e-06  max_mem: 11775M
# [12/13 02:50:57 d2.utils.events]:  eta: 0:09:16  iter: 4459  total_loss: 3.449  loss_cls_stage0: 0.2513  loss_box_reg_stage0: 0.51  loss_cls_stage1: 0.2525  loss_box_reg_stage1: 0.898  loss_cls_stage2: 0.2598  loss_box_reg_stage2: 0.8674  loss_mask: 0.2799  loss_rpn_cls: 0.03666  loss_rpn_loc: 0.1031  time: 1.5317  data_time: 0.0510  lr: 5e-06  max_mem: 11775M
# [12/13 02:51:30 d2.utils.events]:  eta: 0:08:48  iter: 4479  total_loss: 3.674  loss_cls_stage0: 0.2747  loss_box_reg_stage0: 0.5298  loss_cls_stage1: 0.274  loss_box_reg_stage1: 0.8845  loss_cls_stage2: 0.2888  loss_box_reg_stage2: 0.8442  loss_mask: 0.3007  loss_rpn_cls: 0.03679  loss_rpn_loc: 0.1302  time: 1.5321  data_time: 0.1329  lr: 5e-06  max_mem: 11775M
# [12/13 02:51:58 d2.utils.events]:  eta: 0:08:18  iter: 4499  total_loss: 3.574  loss_cls_stage0: 0.2491  loss_box_reg_stage0: 0.5183  loss_cls_stage1: 0.2288  loss_box_reg_stage1: 0.8937  loss_cls_stage2: 0.2523  loss_box_reg_stage2: 0.9075  loss_mask: 0.2656  loss_rpn_cls: 0.03489  loss_rpn_loc: 0.09139  time: 1.5316  data_time: 0.0240  lr: 5e-06  max_mem: 11775M
# [12/13 02:52:28 d2.utils.events]:  eta: 0:07:48  iter: 4519  total_loss: 3.472  loss_cls_stage0: 0.2398  loss_box_reg_stage0: 0.5243  loss_cls_stage1: 0.2463  loss_box_reg_stage1: 0.9153  loss_cls_stage2: 0.2539  loss_box_reg_stage2: 0.9269  loss_mask: 0.292  loss_rpn_cls: 0.03041  loss_rpn_loc: 0.08432  time: 1.5314  data_time: 0.0618  lr: 5e-06  max_mem: 11775M
# [12/13 02:53:04 d2.utils.events]:  eta: 0:07:20  iter: 4539  total_loss: 3.591  loss_cls_stage0: 0.2772  loss_box_reg_stage0: 0.4974  loss_cls_stage1: 0.284  loss_box_reg_stage1: 0.8708  loss_cls_stage2: 0.2795  loss_box_reg_stage2: 0.8644  loss_mask: 0.3068  loss_rpn_cls: 0.0422  loss_rpn_loc: 0.127  time: 1.5326  data_time: 0.3220  lr: 5e-06  max_mem: 11775M
# [12/13 02:53:34 d2.utils.events]:  eta: 0:06:50  iter: 4559  total_loss: 3.504  loss_cls_stage0: 0.2601  loss_box_reg_stage0: 0.5251  loss_cls_stage1: 0.2542  loss_box_reg_stage1: 0.9378  loss_cls_stage2: 0.2574  loss_box_reg_stage2: 0.8973  loss_mask: 0.2814  loss_rpn_cls: 0.03169  loss_rpn_loc: 0.1127  time: 1.5324  data_time: 0.0776  lr: 5e-06  max_mem: 11775M
# [12/13 02:54:05 d2.utils.events]:  eta: 0:06:21  iter: 4579  total_loss: 3.507  loss_cls_stage0: 0.2273  loss_box_reg_stage0: 0.5097  loss_cls_stage1: 0.2321  loss_box_reg_stage1: 0.9397  loss_cls_stage2: 0.2535  loss_box_reg_stage2: 0.8722  loss_mask: 0.297  loss_rpn_cls: 0.02541  loss_rpn_loc: 0.07296  time: 1.5325  data_time: 0.1539  lr: 5e-06  max_mem: 11775M
# [12/13 02:54:31 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold5.json
# [12/13 02:54:31 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/13 02:54:31 d2.data.common]: Serializing 121 elements to byte tensors and concatenating them all ...
# [12/13 02:54:31 d2.data.common]: Serialized dataset takes 1.76 MiB
# [12/13 02:54:31 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold5.json
# [12/13 02:54:31 d2.evaluation.evaluator]: Start inference on 121 batches
# [12/13 02:54:36 d2.evaluation.evaluator]: Inference done 11/121. Dataloading: 0.0012 s/iter. Inference: 0.3921 s/iter. Eval: 0.0479 s/iter. Total: 0.4411 s/iter. ETA=0:00:48
# [12/13 02:54:42 d2.evaluation.evaluator]: Inference done 22/121. Dataloading: 0.0014 s/iter. Inference: 0.3981 s/iter. Eval: 0.0683 s/iter. Total: 0.4680 s/iter. ETA=0:00:46
# [12/13 02:54:47 d2.evaluation.evaluator]: Inference done 34/121. Dataloading: 0.0015 s/iter. Inference: 0.3972 s/iter. Eval: 0.0637 s/iter. Total: 0.4625 s/iter. ETA=0:00:40
# [12/13 02:54:52 d2.evaluation.evaluator]: Inference done 46/121. Dataloading: 0.0015 s/iter. Inference: 0.3959 s/iter. Eval: 0.0602 s/iter. Total: 0.4577 s/iter. ETA=0:00:34
# [12/13 02:54:58 d2.evaluation.evaluator]: Inference done 58/121. Dataloading: 0.0015 s/iter. Inference: 0.3953 s/iter. Eval: 0.0594 s/iter. Total: 0.4564 s/iter. ETA=0:00:28
# [12/13 02:55:03 d2.evaluation.evaluator]: Inference done 69/121. Dataloading: 0.0015 s/iter. Inference: 0.3958 s/iter. Eval: 0.0596 s/iter. Total: 0.4571 s/iter. ETA=0:00:23
# [12/13 02:55:08 d2.evaluation.evaluator]: Inference done 80/121. Dataloading: 0.0015 s/iter. Inference: 0.3961 s/iter. Eval: 0.0609 s/iter. Total: 0.4587 s/iter. ETA=0:00:18
# [12/13 02:55:13 d2.evaluation.evaluator]: Inference done 91/121. Dataloading: 0.0015 s/iter. Inference: 0.3959 s/iter. Eval: 0.0615 s/iter. Total: 0.4591 s/iter. ETA=0:00:13
# [12/13 02:55:18 d2.evaluation.evaluator]: Inference done 103/121. Dataloading: 0.0015 s/iter. Inference: 0.3958 s/iter. Eval: 0.0607 s/iter. Total: 0.4581 s/iter. ETA=0:00:08
# [12/13 02:55:24 d2.evaluation.evaluator]: Inference done 114/121. Dataloading: 0.0015 s/iter. Inference: 0.3963 s/iter. Eval: 0.0611 s/iter. Total: 0.4590 s/iter. ETA=0:00:03
# [12/13 02:55:27 d2.evaluation.evaluator]: Total inference time: 0:00:53.304788 (0.459524 s / iter per device, on 1 devices)
# [12/13 02:55:27 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:45 (0.396313 s / iter per device, on 1 devices)
# [12/13 02:55:27 d2.engine.defaults]: Evaluation results for sartorius_val in csv format:
# [12/13 02:55:27 d2.evaluation.testing]: copypaste: MaP IoU=0.271159100977061
# [12/13 02:55:27 d2.engine.hooks]: Not saving as latest eval score for MaP IoU is 0.27116, not better than best score 0.27288 @ iteration 4355.
# [12/13 02:55:29 d2.utils.events]:  eta: 0:05:51  iter: 4599  total_loss: 3.476  loss_cls_stage0: 0.2182  loss_box_reg_stage0: 0.508  loss_cls_stage1: 0.2337  loss_box_reg_stage1: 0.8767  loss_cls_stage2: 0.2501  loss_box_reg_stage2: 0.9335  loss_mask: 0.2826  loss_rpn_cls: 0.02348  loss_rpn_loc: 0.07316  time: 1.5320  data_time: 0.0237  lr: 5e-06  max_mem: 11775M
# [12/13 02:56:00 d2.utils.events]:  eta: 0:05:22  iter: 4619  total_loss: 3.565  loss_cls_stage0: 0.2401  loss_box_reg_stage0: 0.5334  loss_cls_stage1: 0.2443  loss_box_reg_stage1: 0.8959  loss_cls_stage2: 0.2695  loss_box_reg_stage2: 0.8628  loss_mask: 0.2834  loss_rpn_cls: 0.0405  loss_rpn_loc: 0.1263  time: 1.5321  data_time: 0.0806  lr: 5e-06  max_mem: 11775M
# [12/13 02:56:31 d2.utils.events]:  eta: 0:04:53  iter: 4639  total_loss: 3.56  loss_cls_stage0: 0.2669  loss_box_reg_stage0: 0.5243  loss_cls_stage1: 0.276  loss_box_reg_stage1: 0.9286  loss_cls_stage2: 0.2781  loss_box_reg_stage2: 0.8804  loss_mask: 0.2766  loss_rpn_cls: 0.03518  loss_rpn_loc: 0.09639  time: 1.5321  data_time: 0.1086  lr: 5e-06  max_mem: 11775M
# [12/13 02:57:02 d2.utils.events]:  eta: 0:04:24  iter: 4659  total_loss: 3.697  loss_cls_stage0: 0.2624  loss_box_reg_stage0: 0.532  loss_cls_stage1: 0.2903  loss_box_reg_stage1: 0.927  loss_cls_stage2: 0.2791  loss_box_reg_stage2: 0.8494  loss_mask: 0.2959  loss_rpn_cls: 0.0321  loss_rpn_loc: 0.1273  time: 1.5321  data_time: 0.0961  lr: 5e-06  max_mem: 11775M
# [12/13 02:57:31 d2.utils.events]:  eta: 0:03:54  iter: 4679  total_loss: 3.481  loss_cls_stage0: 0.2104  loss_box_reg_stage0: 0.4857  loss_cls_stage1: 0.1968  loss_box_reg_stage1: 0.8858  loss_cls_stage2: 0.2458  loss_box_reg_stage2: 0.9393  loss_mask: 0.2865  loss_rpn_cls: 0.02461  loss_rpn_loc: 0.06558  time: 1.5318  data_time: 0.0744  lr: 5e-06  max_mem: 11775M
# [12/13 02:58:02 d2.utils.events]:  eta: 0:03:25  iter: 4699  total_loss: 3.474  loss_cls_stage0: 0.2309  loss_box_reg_stage0: 0.4956  loss_cls_stage1: 0.243  loss_box_reg_stage1: 0.8775  loss_cls_stage2: 0.258  loss_box_reg_stage2: 0.9043  loss_mask: 0.288  loss_rpn_cls: 0.02815  loss_rpn_loc: 0.1145  time: 1.5319  data_time: 0.1202  lr: 5e-06  max_mem: 11775M
# [12/13 02:58:32 d2.utils.events]:  eta: 0:02:56  iter: 4719  total_loss: 3.654  loss_cls_stage0: 0.2464  loss_box_reg_stage0: 0.5367  loss_cls_stage1: 0.2694  loss_box_reg_stage1: 0.927  loss_cls_stage2: 0.2842  loss_box_reg_stage2: 0.9099  loss_mask: 0.2822  loss_rpn_cls: 0.02976  loss_rpn_loc: 0.1101  time: 1.5317  data_time: 0.1098  lr: 5e-06  max_mem: 11775M
# [12/13 02:59:06 d2.utils.events]:  eta: 0:02:26  iter: 4739  total_loss: 3.518  loss_cls_stage0: 0.2604  loss_box_reg_stage0: 0.5207  loss_cls_stage1: 0.2612  loss_box_reg_stage1: 0.9102  loss_cls_stage2: 0.2491  loss_box_reg_stage2: 0.8656  loss_mask: 0.2872  loss_rpn_cls: 0.03918  loss_rpn_loc: 0.1245  time: 1.5323  data_time: 0.1854  lr: 5e-06  max_mem: 11775M
# [12/13 02:59:34 d2.utils.events]:  eta: 0:01:57  iter: 4759  total_loss: 3.521  loss_cls_stage0: 0.2494  loss_box_reg_stage0: 0.503  loss_cls_stage1: 0.2492  loss_box_reg_stage1: 0.9107  loss_cls_stage2: 0.2635  loss_box_reg_stage2: 0.9101  loss_mask: 0.2839  loss_rpn_cls: 0.03061  loss_rpn_loc: 0.08213  time: 1.5319  data_time: 0.0327  lr: 5e-06  max_mem: 11775M
# [12/13 03:00:06 d2.utils.events]:  eta: 0:01:27  iter: 4779  total_loss: 3.47  loss_cls_stage0: 0.2188  loss_box_reg_stage0: 0.5002  loss_cls_stage1: 0.2349  loss_box_reg_stage1: 0.9094  loss_cls_stage2: 0.2474  loss_box_reg_stage2: 0.9119  loss_mask: 0.2787  loss_rpn_cls: 0.01577  loss_rpn_loc: 0.1018  time: 1.5322  data_time: 0.1713  lr: 5e-06  max_mem: 11775M
# [12/13 03:00:36 d2.utils.events]:  eta: 0:00:58  iter: 4799  total_loss: 3.507  loss_cls_stage0: 0.1809  loss_box_reg_stage0: 0.4616  loss_cls_stage1: 0.1889  loss_box_reg_stage1: 0.8888  loss_cls_stage2: 0.2251  loss_box_reg_stage2: 0.9106  loss_mask: 0.2886  loss_rpn_cls: 0.0188  loss_rpn_loc: 0.05973  time: 1.5320  data_time: 0.0541  lr: 5e-06  max_mem: 11775M
# [12/13 03:01:04 d2.utils.events]:  eta: 0:00:29  iter: 4819  total_loss: 3.45  loss_cls_stage0: 0.1871  loss_box_reg_stage0: 0.527  loss_cls_stage1: 0.215  loss_box_reg_stage1: 0.9408  loss_cls_stage2: 0.2417  loss_box_reg_stage2: 0.9325  loss_mask: 0.285  loss_rpn_cls: 0.02278  loss_rpn_loc: 0.05127  time: 1.5315  data_time: 0.0454  lr: 5e-06  max_mem: 11775M
# [12/13 03:01:39 d2.utils.events]:  eta: 0:00:00  iter: 4839  total_loss: 3.568  loss_cls_stage0: 0.2078  loss_box_reg_stage0: 0.5062  loss_cls_stage1: 0.214  loss_box_reg_stage1: 0.893  loss_cls_stage2: 0.2646  loss_box_reg_stage2: 0.8891  loss_mask: 0.2762  loss_rpn_cls: 0.02767  loss_rpn_loc: 0.08382  time: 1.5316  data_time: 0.1119  lr: 5e-06  max_mem: 11775M
# [12/13 03:01:39 d2.engine.hooks]: Overall training speed: 4838 iterations in 2:03:29 (1.5316 s / it)
# [12/13 03:01:39 d2.engine.hooks]: Total training time: 2:21:44 (0:18:14 on hooks)
# [12/13 03:01:39 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold5.json
# [12/13 03:01:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/13 03:01:40 d2.data.common]: Serializing 121 elements to byte tensors and concatenating them all ...
# [12/13 03:01:40 d2.data.common]: Serialized dataset takes 1.76 MiB
# [12/13 03:01:40 d2.data.datasets.coco]: Loaded 121 images in COCO format from /content/drive/MyDrive/Kaggle/Sartorius/input/fixed_fold/coco_cell_valid_fold5.json
# [12/13 03:01:40 d2.evaluation.evaluator]: Start inference on 121 batches
# [12/13 03:01:45 d2.evaluation.evaluator]: Inference done 11/121. Dataloading: 0.0012 s/iter. Inference: 0.3922 s/iter. Eval: 0.0489 s/iter. Total: 0.4423 s/iter. ETA=0:00:48
# [12/13 03:01:50 d2.evaluation.evaluator]: Inference done 21/121. Dataloading: 0.0014 s/iter. Inference: 0.4128 s/iter. Eval: 0.0756 s/iter. Total: 0.4900 s/iter. ETA=0:00:48
# [12/13 03:01:55 d2.evaluation.evaluator]: Inference done 32/121. Dataloading: 0.0016 s/iter. Inference: 0.4094 s/iter. Eval: 0.0669 s/iter. Total: 0.4781 s/iter. ETA=0:00:42
# [12/13 03:02:01 d2.evaluation.evaluator]: Inference done 43/121. Dataloading: 0.0016 s/iter. Inference: 0.4101 s/iter. Eval: 0.0700 s/iter. Total: 0.4819 s/iter. ETA=0:00:37
# [12/13 03:02:06 d2.evaluation.evaluator]: Inference done 55/121. Dataloading: 0.0016 s/iter. Inference: 0.4062 s/iter. Eval: 0.0644 s/iter. Total: 0.4724 s/iter. ETA=0:00:31
# [12/13 03:02:11 d2.evaluation.evaluator]: Inference done 66/121. Dataloading: 0.0016 s/iter. Inference: 0.4040 s/iter. Eval: 0.0637 s/iter. Total: 0.4694 s/iter. ETA=0:00:25
# [12/13 03:02:16 d2.evaluation.evaluator]: Inference done 77/121. Dataloading: 0.0016 s/iter. Inference: 0.4043 s/iter. Eval: 0.0662 s/iter. Total: 0.4723 s/iter. ETA=0:00:20
# [12/13 03:02:22 d2.evaluation.evaluator]: Inference done 88/121. Dataloading: 0.0015 s/iter. Inference: 0.4039 s/iter. Eval: 0.0671 s/iter. Total: 0.4728 s/iter. ETA=0:00:15
# [12/13 03:02:27 d2.evaluation.evaluator]: Inference done 100/121. Dataloading: 0.0015 s/iter. Inference: 0.4024 s/iter. Eval: 0.0653 s/iter. Total: 0.4694 s/iter. ETA=0:00:09
# [12/13 03:02:32 d2.evaluation.evaluator]: Inference done 111/121. Dataloading: 0.0015 s/iter. Inference: 0.4026 s/iter. Eval: 0.0665 s/iter. Total: 0.4709 s/iter. ETA=0:00:04
# [12/13 03:02:37 d2.evaluation.evaluator]: Total inference time: 0:00:54.486388 (0.469710 s / iter per device, on 1 devices)
# [12/13 03:02:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.401941 s / iter per device, on 1 devices)
# [12/13 03:02:37 d2.engine.defaults]: Evaluation results for sartorius_val in csv format:
# [12/13 03:02:37 d2.evaluation.testing]: copypaste: MaP IoU=0.2714590017157402
# [12/13 03:02:37 d2.engine.hooks]: Not saving as latest eval score for MaP IoU is 0.27146, not better than best score 0.27288 @ iteration 4355.
